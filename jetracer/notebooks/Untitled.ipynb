# %%
import ipywidgets.widgets as widgets
from jetracer.nvidia_racecar import NvidiaRacecar
import traitlets
import time

car = NvidiaRacecar()
throttle_slider = widgets.FloatSlider(description='throttle', min=0.0, max=1.0, step=0.01, orientation='horizontal')
steering_slider = widgets.FloatSlider(description='steering', min=0.0, max=1.0, step=0.01, orientation='horizontal')
display(throttle_slider)
display(steering_slider)
while True:
    car.steering = 0.6
    car.steering_offset = 0.2
    car.throttle = 0.6
    car.steering_gain = 0
    car.throttle_gain = 0.8
    print(car.steering_motor.throttle)
    print(car.throttle_motor.throttle)
    print(car.steering_gain)
    print(car.throttle_gain)
# Out:
# FloatSlider(value=0.0, description='throttle', max=1.0, step=0.01)
# FloatSlider(value=0.0, description='steering', max=1.0, step=0.01)
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# 0.1761305678340701
# 0.0
# 0.8
# -0.3896633798027882
# ...

# %%
print(car.steering_gain)
print(car.throttle_gain)
print(car.steering_motor.throttle)
print(car.throttle_motor.throttle)
# Out:
# 0.8
# 0.8
# -0.3896633798027882
# 0.4753485209112547
